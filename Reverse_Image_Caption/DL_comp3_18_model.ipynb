# %% [markdown]
# # Environment setting

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow.keras import layers
import os
#from transformers import BertTokenizer, TFBertModel

import string
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import random
import time
from pathlib import Path

import re
from IPython import display

import tensorflow_hub as hub
import tensorflow_text


MAX_SEQ_LENGTH = 20

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
COMP3_DIR = "/home/yuan65536/DL-hw/kaggle03/"

# %%
dictionary_path = COMP3_DIR + 'dictionary'
vocab = np.load(dictionary_path + '/vocab.npy')
print('there are {} vocabularies in total'.format(len(vocab)))

word2Id_dict = dict(np.load(dictionary_path + '/word2Id.npy'))
id2word_dict = dict(np.load(dictionary_path + '/id2Word.npy'))
print('Word to id mapping, for example: %s -> %s' % ('flower', word2Id_dict['flower']))
print('Id to word mapping, for example: %s -> %s' % ('1', id2word_dict['1']))
print('Tokens: <PAD>: %s; <RARE>: %s' % (word2Id_dict['<PAD>'], word2Id_dict['<RARE>']))
# Out:
# there are 5427 vocabularies in total
# Word to id mapping, for example: flower -> 1
# Id to word mapping, for example: 1 -> flower
# Tokens: <PAD>: 5427; <RARE>: 5428

# %% [markdown]
# ## Preprocess Text

# %%
def sent2IdList(line, MAX_SEQ_LENGTH=20):
    MAX_SEQ_LIMIT = MAX_SEQ_LENGTH
    padding = 0
    
    # data preprocessing, remove all puntuation in the texts
    prep_line = re.sub('[%s]' % re.escape(string.punctuation), ' ', line.rstrip())
    prep_line = prep_line.replace('-', ' ')
    prep_line = prep_line.replace('-', ' ')
    prep_line = prep_line.replace('  ', ' ')
    prep_line = prep_line.replace('.', '')
    tokens = prep_line.split(' ')
    tokens = [
        tokens[i] for i in range(len(tokens))
        if tokens[i] != ' ' and tokens[i] != ''
    ]
    l = len(tokens)
    padding = MAX_SEQ_LIMIT - l
    
    # make sure length of each text is equal to MAX_SEQ_LENGTH, and replace the less common word with <RARE> token
    for i in range(padding):
        tokens.append('<PAD>')
    line = [
        word2Id_dict[tokens[k]]
        if tokens[k] in word2Id_dict else word2Id_dict['<RARE>']
        for k in range(len(tokens))
    ]

    return line

text = "the flower shown has yellow anther red pistil and bright red petals."
print(text)
print(sent2IdList(text))
# Out:
# the flower shown has yellow anther red pistil and bright red petals.
# ['9', '1', '82', '5', '11', '70', '20', '31', '3', '29', '20', '2', '5427', '5427', '5427', '5427', '5427', '5427', '5427', '5427']

# %% [markdown]
# ## Dataset

# %%
data_path = COMP3_DIR + 'dataset'
df = pd.read_pickle(data_path + '/text2ImgData.pkl')
num_training_sample = len(df)
n_images_train = num_training_sample
print('There are %d image in training data' % (n_images_train))
# Out:
# There are 7370 image in training data

# %%
df.head(5)
# Out:
#                                                Captions  \
# ID
# 6734  [[9, 2, 17, 9, 1, 6, 14, 13, 18, 3, 41, 8, 11,...
# 6736  [[4, 1, 5, 12, 2, 3, 11, 31, 28, 68, 106, 132,...
# 6737  [[9, 2, 27, 4, 1, 6, 14, 7, 12, 19, 5427, 5427...
# 6738  [[9, 1, 5, 8, 54, 16, 38, 7, 12, 116, 325, 3, ...
# 6739  [[4, 12, 1, 5, 29, 11, 19, 7, 26, 70, 5427, 54...
#
#                          ImagePath
# ID
# 6734  ./102flowers/image_06734.jpg
# 6736  ./102flowers/image_06736.jpg
# 6737  ./102flowers/image_06737.jpg
# 6738  ./102flowers/image_06738.jpg
# 6739  ./102flowers/image_06739.jpg

# %%
def id_to_string(df):
    for i in range(len(df)):
    #     if i > 1: break
        captures_word = []
        for cap in df['Captions'].iloc[i]:
            capture_word = ''
            for id_ in cap:
                word = id2word_dict[id_]
                if word == '<PAD>':
                    continue
                capture_word += word+' '
#             print(capture_word)
            captures_word.append(capture_word)
        df['Captions'].iloc[i] = captures_word

# %%
df.head(5)
# Out:
#                                                Captions  \
# ID
# 6734  [[9, 2, 17, 9, 1, 6, 14, 13, 18, 3, 41, 8, 11,...
# 6736  [[4, 1, 5, 12, 2, 3, 11, 31, 28, 68, 106, 132,...
# 6737  [[9, 2, 27, 4, 1, 6, 14, 7, 12, 19, 5427, 5427...
# 6738  [[9, 1, 5, 8, 54, 16, 38, 7, 12, 116, 325, 3, ...
# 6739  [[4, 12, 1, 5, 29, 11, 19, 7, 26, 70, 5427, 54...
#
#                          ImagePath
# ID
# 6734  ./102flowers/image_06734.jpg
# 6736  ./102flowers/image_06736.jpg
# 6737  ./102flowers/image_06737.jpg
# 6738  ./102flowers/image_06738.jpg
# 6739  ./102flowers/image_06739.jpg

# %% [markdown]
# ## Create Dataset by Dataset API

# %%
# in this competition, you have to generate image in size 64x64x3
IMAGE_HEIGHT = 64
IMAGE_WIDTH = 64
IMAGE_CHANNEL = 3

def training_data_generator(caption, image_path):

    img = tf.io.read_file(image_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, size=[IMAGE_HEIGHT, IMAGE_WIDTH])
    img.set_shape([IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNEL])
    img = img * 2. -1.

    return img, caption

def dataset_generator(filenames, batch_size, data_generator):
    # load the training data into two NumPy arrays
    df = pd.read_pickle(filenames)
    id_to_string(df)
    captions = df['Captions'].values
    caption = []
    # each image has 1 to 10 corresponding captions
    # we choose one of them randomly for training
    for i in range(len(captions)):

        caption.append(random.choice(captions[i]))
    caption = np.asarray(caption)

    for i in df.index:
        df['ImagePath'].loc[i] = COMP3_DIR + df['ImagePath'].loc[i][2:]
        
    image_path = df['ImagePath'].values
    assert caption.shape[0] == image_path.shape[0]
    
    dataset = tf.data.Dataset.from_tensor_slices((caption, image_path))
    dataset = dataset.map(data_generator, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(len(caption)).batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
BATCH_SIZE = 64
dataset = dataset_generator(data_path + '/text2ImgData.pkl', BATCH_SIZE, training_data_generator)

# %% [markdown]
# ## Conditional GAN Model
# ## Text Encoder
#
# 直接import tensorflow提供的universal sentence encoder幫助我們將句子變成embedding
# 然而這邊有點矛盾，因為這個encoder出來的照片沒有原本RNN架構的圖片漂亮，但是這個universal sentence encoder的分數卻比較高，應該有更好的改進方式，但我們決定利用kaggle的分數為主來選擇使用的encoder，也有想用過其他的encoder，但是這個USC的架構最好使用，就決定使用這個encoder為主了

# %%
class TextEncoder(tf.keras.Model):
    """
    Encode text (a captio n) into hidden representation
    input: text, which is a text
    output: embedding
    """
    def __init__(self):
        super(TextEncoder, self).__init__()
        module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
        self.text_encoder = hub.load(module_url)

    
    def call(self, text):
        return self.text_encoder(text)

# %% [markdown]
# ## Define function

# %%
class conv(tf.keras.Model):
    def __init__(self, filters, size, stride):
        super(conv, self).__init__()
        self.conv = layers.Conv2D(filters, size, stride, padding="same", kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02), use_bias=False)
        self.bn = layers.BatchNormalization()
        

    def call(self, inputs, training=False):
        x = self.bn(self.conv(inputs), training=training)
        return x
'''class conv_relu(tf.keras.Model):
    def __init__(self, filters, size, stride):
        super(conv_relu, self).__init__()
        self.conv = layers.Conv2D(filters, size, stride, padding="same", kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02), use_bias=False)
        self.bn =layers.BatchNormalization()
        self.ReLU = layers.ReLU()

    def call(self, inputs, training=False):
        x = self.bn(self.conv(inputs), training=training)
        x = self.ReLU(x)
        return x'''    


class conv_leaky_relu(tf.keras.Model):
    def __init__(self, filters, size, stride):
        super(conv_leaky_relu, self).__init__()
        self.conv = layers.Conv2D(filters, size, stride, padding="same", kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02),  use_bias=False)
        self.bn = layers.BatchNormalization()
        self.LeakyReLU = layers.LeakyReLU(0.2)

    def call(self, inputs, training=False):
        x = self.bn(self.conv(inputs), training=training)
        x = self.LeakyReLU(x)
        return x
    
def UpSampleBlock(filters_num):
        
    return tf.keras.Sequential([
                tf.keras.layers.UpSampling2D(),
                tf.keras.layers.Conv2D(filters=filters_num, kernel_size=3, strides=1, padding='SAME',
                                       use_bias=False, kernel_initializer=tf.keras.initializers.TruncatedNormal(mean=0.0, stddev=0.02)),
                tf.keras.layers.BatchNormalization(),

            ])

# %% [markdown]
# ## Generator
#
# 1226將G的relu 全部都換成leaky_relu試試

# %%
class Generator(tf.keras.Model):
    def __init__(self, hparas):
        super(Generator, self).__init__()
        self.hparas = hparas

        self.hparas = hparas
        self.t_dim = 128
        self.gf_dim = 128
        self.image_size = 64
        self.c_dim = 3
        
        self.text_fc = tf.keras.layers.Dense(128, kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02),
                                              use_bias=False)
         
        self.dense_block = tf.keras.Sequential([
                tf.keras.layers.Dense(128*8*4*4, kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02),use_bias=False),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Reshape((4, 4, 128*8))
            ])
        #self.conv1_1 = conv_leaky_relu(256,1,1)
        #self.conv1_2 = conv_leaky_relu(256,3,1)
        #self.conv1_3 = conv(1024,3,1)
        
        self.upsample1 = UpSampleBlock(filters_num=128*4)
        
        self.conv2_1 = conv_leaky_relu(128,1,1)
        self.conv2_2 = conv_leaky_relu(128,3,1)
        self.conv2_3 = conv(512,3,1)
        
        self.upsample2 = UpSampleBlock(128*2)
        self.upsample3 = UpSampleBlock(128)
        #self.upsample4 = UpSampleBlock(128)
        self.upsample4 = UpSampleBlock(64)
        self.conv_o = conv(3, 3, 1)
   

    def call(self, text, noise_z, training):

        x_in = tf.concat([noise_z, text], axis=1)

        x_0 = self.dense_block(x_in, training=training) #(-1*4*4*1024)
        
        x_2 = self.upsample1(x_0)  #(-1*8*8*512)
        x_2 = tf.nn.relu(x_2)
        x = self.conv2_1(x_2)
        x = self.conv2_2(x)
        x = self.conv2_3(x)
        
        x_3 = tf.add_n([x_2, x])  
        x_3_output = tf.nn.relu(x_3) 

        x_4 = self.upsample2(x_3_output)  #(-1*16*16*256)
        x_4 = tf.nn.relu(x_4)
        x_5 = self.upsample3(x_4)  #(-1*32*32*128)
        x_5 = tf.nn.relu(x_5)
        x_6 = self.upsample4(x_5) #(-1*64*64*256)
        x_6 = tf.nn.relu(x_6)
        x_o =  self.conv_o(x_6)
        
        outputs = tf.nn.tanh(x_o)
        logits = x_o
        
        # return logits, output, mean, logvar
        return logits, outputs

# %% [markdown]
# ## Discriminator

# %%
class Discriminator(tf.keras.Model):
    def __init__(self, hparas):
        super(Discriminator, self).__init__()
        self.hparas = hparas
        self.conv0 = layers.Conv2D(64, 4, 2, padding="same", kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02),
                                   use_bias=False)
        self.conv1 = conv_leaky_relu(128,4,2)
        self.conv2 = conv_leaky_relu(256,4,2)
        self.conv3 = conv_leaky_relu(512,4,2)
        
        self.conv4_1 = conv_leaky_relu(128,1,1)
        self.conv4_2 = conv_leaky_relu(128,3,1)
        self.conv4_3 = conv_leaky_relu(512,3,1)
        
        self.text_fc = tf.keras.layers.Dense(128, kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02),  use_bias=False)
        self.leakyRelu1 = layers.LeakyReLU(0.1)
        self.conv5 = conv_leaky_relu(512,3,1)
        self.conv6 = layers.Conv2D(1, 4, 4, padding="same", kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.02),
                                    use_bias=False)
    def call(self, input_image, input_text, training):
        x = self.conv0(input_image,training=training)
        x = tf.nn.leaky_relu(x)
        x = self.conv1(x,training=training)
        x = self.conv2(x,training=training)
        x = self.conv3(x,training=training)

        x_1 = self.conv4_1(x,training=training)
        x_1 = self.conv4_2(x_1,training=training)
        x_1 = self.conv4_3(x_1,training=training)

        x_2 = tf.add_n([x_1, x])
        x_2 = tf.nn.leaky_relu(x_2)

        t = self.text_fc(input_text,training=training)
#         t = self.leakyRelu1(t)
        t = tf.reshape(t, (-1, 1, 1, 128))
        t = tf.tile(t, [1, 4, 4, 1])

        x_t_concat = tf.concat([x_2, t], axis=3)

        x_t =  self.conv5(x_t_concat,training=training)
        logits = self.conv6(x_t,training=training)
        output = tf.nn.sigmoid(logits)
        #     logits, outputs
        return logits, output

# %% [markdown]
# # Hyperparameter and model declaration

# %%
hparas = {
    'MAX_SEQ_LENGTH': 20,                     # maximum sequence length
#     'EMBED_DIM': 256,                         # word embedding dimension
    'EMBED_DIM': 512,
    'VOCAB_SIZE': len(word2Id_dict),          # size of dictionary of captions
    'RNN_HIDDEN_SIZE': 128,                   # number of RNN neurons
    'Z_DIM': 512,                             # random noise z dimension
    'DENSE_DIM': 128,                         # number of neurons in dense layer
    'IMAGE_SIZE': [64, 64, 3],                # render image size
    'BATCH_SIZE': 64,
    'LR': 1e-4,
    'LR_DECAY': 0.5,
    'BETA_1': 0.5,
    'N_EPOCH': 1000,
    'N_SAMPLE': num_training_sample,          # size of training data
    'CHECKPOINTS_DIR': './checkpoints/demo_test',  # checkpoint path
    'PRINT_FREQ': 1,                          # printing frequency of loss
    'SHOW_IMAGES': 20
}

# %%
text_encoder = TextEncoder()
generator = Generator(hparas)
discriminator = Discriminator(hparas)

# %% [markdown]
# ## Loss Function and Optimization

# %% [markdown]
# 原本的loss只考慮(正確圖片、正確敘述)(錯誤圖片、正確敘述) 但是沒有考慮到(正確圖片、錯誤敘述)的情況，因此我們多加上一個loss，結果發現加上之後效果就有大幅提升

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real_logits, fake_logits, wrong_logits):

    # output value of real image should be 1
    real_loss = cross_entropy(tf.ones_like(real_logits), real_logits)
    # output value of fake image should be 0
    fake_loss = cross_entropy(tf.zeros_like(fake_logits), fake_logits)

    wrong_loss = cross_entropy(tf.zeros_like(wrong_logits), wrong_logits)

    total_loss = real_loss + 0.5*(fake_loss + wrong_loss)

    return total_loss

def generator_loss(fake_output):
    # output value of fake image should be 0
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
# we use seperated optimizers for training generator and discriminator
generator_optimizer = tf.keras.optimizers.Adam(hparas['LR'])
discriminator_optimizer = tf.keras.optimizers.Adam(hparas['LR'])

# %% [markdown]
# # Check points
#
# 1226 改變一下noise的分布 試試看
# 前幾個epoch看起來好像整陀爛掉，等全部train完再試試(X)#沒用

# %%
# one benefit of tf.train.Checkpoint() API is we can save everything seperately
checkpoint_dir = hparas['CHECKPOINTS_DIR']
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 text_encoder=text_encoder,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
print(checkpoint)
# Out:
# <tensorflow.python.training.tracking.util.Checkpoint object at 0x7f9bd3e847b8>

# %% [markdown]
# ## train step

# %%
@tf.function
def train_step_D(real_image, caption):
    # random noise for generator

    noise = tf.random.normal(shape=[hparas['BATCH_SIZE'], hparas['Z_DIM']])
    
    wrong_caption = tf.concat([caption[1:], tf.expand_dims(caption[0], 0)], axis=0)
    with tf.GradientTape() as disc_tape:
        text_embed = text_encoder(caption)
        wrong_text_embed = text_encoder(wrong_caption)
        _, fake_image = generator(text_embed, noise, True)
        real_logits, real_output = discriminator(real_image, text_embed, True)
        fake_logits, fake_output = discriminator(fake_image, text_embed, True)
        wrong_logits, wrong_output = discriminator(real_image, wrong_text_embed, training=True)
        
        # for gradient penalty
        epsilon = tf.compat.v2.random.uniform([hparas['BATCH_SIZE'], 1, 1, 1], 0., 1.)
        mix_image = epsilon*real_image + (1. - epsilon)*fake_image
            
        mix_logits, mix_output = discriminator(mix_image, text_embed, training=True)
           
        grad = tf.square(tf.sqrt(tf.reduce_sum(tf.square(tf.gradients(mix_logits, mix_image)[0]), axis=[1, 2])) - 1.)

        g_loss = generator_loss(fake_logits)
        d_loss = discriminator_loss(real_logits, fake_logits, wrong_logits) + 10.*tf.reduce_mean(grad)

    grad_d = disc_tape.gradient(d_loss, discriminator.trainable_variables)

    discriminator_optimizer.apply_gradients(zip(grad_d, discriminator.trainable_variables))
    
    return g_loss, d_loss

# %%
@tf.function
def train_step_G(real_image, caption):
    # random noise for generator
 
    noise = tf.random.normal(shape=[hparas['BATCH_SIZE'], hparas['Z_DIM']])
    
    wrong_caption = tf.concat([caption[1:], tf.expand_dims(caption[0], 0)], axis=0)

    with tf.GradientTape() as gen_tape:
        text_embed = text_encoder(caption)
        wrong_text_embed = text_encoder(wrong_caption)
        _, fake_image = generator(text_embed, noise, True)
        real_logits, real_output = discriminator(real_image, text_embed, True)
        fake_logits, fake_output = discriminator(fake_image, text_embed, True)
        wrong_logits, wrong_output = discriminator(real_image, wrong_text_embed, training=True)
        
        # for gradient penalty
        epsilon = tf.compat.v2.random.uniform([hparas['BATCH_SIZE'], 1, 1, 1], 0., 1.)
        mix_image = epsilon*real_image + (1. - epsilon)*fake_image
            
        mix_logits, mix_output = discriminator(mix_image, text_embed, training=True)
           
        grad = tf.square(tf.sqrt(tf.reduce_sum(tf.square(tf.gradients(mix_logits, mix_image)[0]), axis=[1, 2])) - 1.)

        g_loss = generator_loss(fake_logits)
        d_loss = discriminator_loss(real_logits, fake_logits, wrong_logits) + 10.*tf.reduce_mean(grad)

    grad_g = gen_tape.gradient(g_loss, generator.trainable_variables)

    generator_optimizer.apply_gradients(zip(grad_g, generator.trainable_variables))
    
    return g_loss, d_loss

# %% [markdown]
# ## test step

# %%
@tf.function
def test_step(caption, noise):
    text_embed = text_encoder(caption)
    print(text_embed)
    _, fake_image = generator(text_embed, noise)
    return fake_image

# %% [markdown]
# ## Visualiztion

# %%
def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j*h:j*h+h, i*w:i*w+w, :] = image
    return img

def imsave(images, size, path):
    # getting the pixel values between [0, 1] to save it
    return plt.imsave(path, merge(images, size)*0.5 + 0.5)

def save_images(images, size, image_path):
    return imsave(images, size, image_path)

# %%
def sample_generator(caption, batch_size):
    caption = np.asarray(caption)
    caption = caption.astype(np.int)
    dataset = tf.data.Dataset.from_tensor_slices(caption)
    dataset = dataset.batch(batch_size)
    return dataset

# %%
ni = int(np.ceil(np.sqrt(hparas['BATCH_SIZE'])))
sample_size = hparas['BATCH_SIZE']
sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
sample_sentence = ["the flower shown has yellow anther red pistil and bright red petals."] * int(sample_size/ni) + \
                  ["this flower has petals that are yellow, white and purple and has dark lines"] * int(sample_size/ni) + \
                  ["the petals on this flower are white with a yellow center"] * int(sample_size/ni) + \
                  ["this flower has a lot of small round pink petals."] * int(sample_size/ni) + \
                  ["this flower is orange in color, and has petals that are ruffled and rounded."] * int(sample_size/ni) + \
                  ["the flower has yellow petals and the center of it is brown."] * int(sample_size/ni) + \
                  ["this flower has petals that are blue and white."] * int(sample_size/ni) +\
                  ["these white flowers have petals that start off white in color and end in a white towards the tips."] * int(sample_size/ni)

sample_sentence = tf.data.Dataset.from_tensor_slices(sample_sentence).batch(hparas['BATCH_SIZE'])

# %% [markdown]
# ## Training
#
# 和GAN的lab一樣使用每5次生成，更新一次discriminator
# 由於embedding改為使用universal sentence encoder沒有用到RNN 所以input進train裡面就沒有hidden，改為在training Generator的時候直接將sentence轉為embedding，並且跟noise concate在一起，之後丟到Generator裡面做training

# %%
# ratio of training step D:G = 5:1
ratio = 6

def train(dataset, epochs):
    steps_per_epoch = int(hparas['N_SAMPLE'] / hparas['BATCH_SIZE'])
    turn = 0
    
    for epoch in range(hparas['N_EPOCH']):
        g_total_loss = 0
        d_total_loss = 0
        start = time.time()
        
        for image, caption in dataset:
            if (turn + 1) == ratio:
                g_loss, d_loss = train_step_G(image, caption)
            else:
                g_loss, d_loss = train_step_D(image, caption)
            turn = (turn + 1) % ratio
            g_total_loss += g_loss
            d_total_loss += d_loss
            
        time_tuple = time.localtime()
        time_string = time.strftime("%m/%d/%Y, %H:%M:%S", time_tuple)
            
        print("Epoch {}, gen_loss: {:.4f}, disc_loss: {:.4f}".format(epoch+1,
                                                                     g_total_loss/steps_per_epoch,
                                                                     d_total_loss/steps_per_epoch))
        print('Time for epoch {} is {:.4f} sec'.format(epoch+1, time.time()-start))
        
        # save the model
        if (epoch + 1) % 5 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)
        
        # visualization
        if (epoch + 1) % hparas['PRINT_FREQ'] == 0:
            for caption in sample_sentence:
                fake_image = test_step(caption, sample_seed)
            save_images(fake_image, [ni, ni], './samples/demo_test/train_{:02d}.jpg'.format(epoch))
            
        # show the generated images
        if (epoch + 1) % hparas['SHOW_IMAGES'] == 0:    
            img = Image.open('./samples/demo_test/train_{:02d}.jpg'.format(epoch))
            display.display(img)

# %%
train(dataset, hparas['N_EPOCH'])

# %% [markdown]
# ## Testing dataset

# %%
def id_to_string_for_testdata(ids):
    length = len(ids)
    caption = []
    for i in range(length):
        caption.append(ids[i])
    for cap in range(len(caption)):
        caption_text = ""
        for word in caption[cap]:
            if id2word_dict[word] != '<PAD>':
                caption_text += id2word_dict[word]
                caption_text += ' '
        caption[cap] = caption_text
    strings = np.asarray(caption)
    return strings

def testing_dataset_generator(batch_size):
    caption = id_to_string_for_testdata(captions)

    index = data['ID'].values
    index = np.asarray(index)
    
    dataset = tf.data.Dataset.from_tensor_slices((caption, index))
    dataset = dataset.repeat().batch(batch_size)
    
    return dataset

# %%
data = pd.read_pickle(data_path +'/testData.pkl')
captions = data['Captions'].values
NUM_TEST = len(captions)
EPOCH_TEST = int(NUM_TEST / hparas['BATCH_SIZE'])

# %%
testing_dataset = testing_dataset_generator(hparas['BATCH_SIZE'])

# %% [markdown]
# ## Inferece

# %%
def inference(dataset):
#     hidden = text_encoder.initialize_hidden_state()
    sample_size = hparas['BATCH_SIZE']
    sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
    
    step = 0
    start = time.time()
    for captions, idx in dataset:
        print(captions.shape)
        if step > EPOCH_TEST:
            break
        
        fake_image = test_step(captions, sample_seed)
        step += 1
        for i in range(hparas['BATCH_SIZE']):
            plt.imsave('./inference/demo_test/inference_{:04d}.jpg'.format(idx[i]), fake_image[i].numpy()*0.5 + 0.5)
            #print("number of captions:",idx[i])
            print('captions: ',captions[i])
            
    print('Time for inference is {:.4f} sec'.format(time.time()-start))

# %%
s1=tf.convert_to_tensor([
    'this flower has a lot of tall orange petals and a lot of brown anthers ',
   'this flower has a lot of tall orange petals and a lot of brown anthers ',
   'this flower has a lot of tall orange petals and a lot of brown anthers ',
   'this flower has a lot of tall orange petals and a lot of brown anthers ',
   'this flower has a lot of tall orange petals and a lot of brown anthers '])
print(s1.shape)
sample_size =5

sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
print(sample_seed.shape)
for i in range(5):
            fake_image=test_step(s1,sample_seed)
            plt.imsave('./inference/demo_final/temp5/inference_{:04d}.jpg'.format(i), fake_image[i].numpy()*0.5 + 0.5)
# Out:
# (5,)
# (5, 512)

# %%
print(checkpoint_dir)
# Out:
# ./checkpoints/demo_test

# %%
checkpoint.restore(checkpoint_dir + '/ckpt-172')

# %%
inference(testing_dataset)
# Out:
# (64,)
# captions:  tf.Tensor(b'this white and purple flower has fragile petals and soft stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has four large wide pink petals with white centers and vein like markings ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with broad white and pink ribbed petals and yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'one prominet pistil with alarger stigam and many stamens with anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'leaves are green in color petals are light pink in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is bright pink with overlapping petals and a lime green pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and yellow in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has 4 leaves three are purple and yellow with lines and one is solid purple ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pretty flower has dark and white petals on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is trumpet shaped with a light pink petal and green sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a few bright pink petals that turn more white in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white in color with petals that are wavy and uneven ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower is red in color with a long pedicel with leaves on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a brown center surrounded by layers of long yellow petals with rounded tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the green sepals are ditached from the yellow part of the flower ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a lot of petals mostly in orange color but the middle portion is more on yellow color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a lot of tall orange petals and a lot of brown anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with mid sized orange petals and central cluster of yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are orange with yellow center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has many yellow petals surround the red stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has orange yellow petals and a light yellow ring around the center of it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are ruffled on the ends ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has orange petals with brown stamen that float ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are orange with black dots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has light red petals with brown spots on it and light red stamen with brown anthers on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are orange with red spots and a long stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with a white stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has white petals with yellow on the inside center petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower is big and white with soft smooth and big petals that has stamen in the centre ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has white petals with a stamen that is yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with very large broad white petals and red and green central stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has 3 top white petals and 3 lower petals that curve inwards protecting the stamen and pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and yellow in color with petals that are rounded and large ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are orange with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the tropical flower are yellow in color and extend from a green stem ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has pointy yellow petals with blue pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange and blue in color with petals that are pointy and skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a several pieces of yellow colored petals that looks similar to its leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with long tall orange petals green sepals marred with red and green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has a bright yellow petal along with a multi colored petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are purple and triangle shape ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the light blue flowers has small round petals and green stems ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are cone shaped and dark purple ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple and white in color and has petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a cluster of tubular flowers extend downward forming a spike each flower is white with purple tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pedicel hold many flowers with many petals on them ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a gradually changing colored petals ranging from violet to the outer part to white towards the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a small flower with many purple and white petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a lot of small white petals and no visible stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has many overlapping petals that are bright yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this bright pink flower has several fluttery petals and a tubular center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has several petals that are purple and white ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are very skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower features a set of dense bristly yellow petals and stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are skinny and long ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long pink petals and long white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has white pistil surrounded by green and pinkish petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and white in color with petals that are pointed at the tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has pointy green pedicel and purple petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the visible petals on the plant are thin and purple while the stem has spikes on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower s purple colour is lovely and the leaves are pointy petals by the many ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flowers has spiky needle shapd green petals with perple stamen ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'this thorny flower has purple pointed petals a bulbous ovary and a pointed pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has big yellow petals and yellow stamen along with a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flowers are yellow in color with green leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are yellow with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are ruffled and wavy ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow with black lines ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are large and dark yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow curled inward petals and pointed leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are wavy and thin ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the large bright yellow pedals fold together on top of each other with no sepal or stamen visible ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow petals yellow stamen and a green stem among green leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has thin pink petals as its main feature ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and red in color with petals that are drooping down ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and red in color with petals that are oval shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this large purple flower has thin droopy petals and a thick rounded center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pin and red in color with petals that are drooping down ward ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and brown in color with petals that are skinny oval shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has several pink petals and an orange center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and brown in color with petals that are drooping down ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are pink with orange stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and red in color with petals that are drooping down ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has skinny dark pink petals and a large round pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long tapered lavender petals around prominent brown stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a dull pink petaled flower with bright red tipped pistils ', shape=(), dtype=string)
# captions:  tf.Tensor(b'sepals are gren in colo petals are light pink in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and yellow in color with petals that are drooping down ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long thin pink petals and long red stamens in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and orange in color with petals that are drooping down ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are red with white edges and red filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has lavender petals with maroon stripes and brown anther filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are magenta with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and yellow in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with red anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with a pink stripe in the center and red stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are striped near the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flowers are pink in color with light yellow patches and specks of black details ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the white flower has petals that are soft smooth thin and separately around stamens in single layer ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has six plain pale yellow petals that alternate with three dark yellow speckled petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is blue in color with petals that have veins ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with blue anther and white filament ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a purple petal wrapped around the flower with a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a purple flower with stripes on the petals and a long stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a single white petal with pale orange stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower consists of a single large white petal which surrounds a deep thick yellow stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with a yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red yellow and green in color with petals that are wavy and pointed ', shape=(), dtype=string)
# captions:  tf.Tensor(b'long thin crinkled yellow and orange petals strung out around the pistil in an enclosing manner ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has large yellow petals and long yellow stamen on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with green edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple in color with petals that are wavy ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple and ruffled together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the numerous small purple and white petals surround many individual stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the small lavender flower has many small arrow shaped lavender petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with pink dots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red and black in color with petals that are spotted ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has a purple pedicel with a droopy purple petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are drooping with burgundy and white spots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this unique flower hang down from its pedicel with purple and white patterned petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has red petals that are in the shape of a pine cone ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are pink in color and have leaves that are green ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a beautiful color of pinkish red with equal overlapping petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with many layers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower shown has blue petals in the shapes of blueberries and a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flowers has a very beautiful bell like shape that s purple in color ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'a large group of bells that are blue on this flower ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is bright purple with many pedals that are roundish whth pale white outer petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are purple and shaped like spheres ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has shiny red petals black filaments and a brown pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red in color with petals that are rounded in shape ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has red flowing petals and a small pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a black pistil with a red petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the bowl shaped violet flower is soft smooth and separately arranged around stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has red petals with green sepals and pedicels ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red and very thin ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals are the flower are yellow and spiky while the sepals are pointed and green ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are stacked red combs ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is blue in color with petals that are star shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a flower that has dark blue petals and a yellow stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple in color with petals that are curled upward ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower consists of myriad purple tamens its petals are green and spiky and not as prominent ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple and white in color with petals that are curled upward ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a lot of green petals and a lot of bright purple stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has thin purple spike like petals coming from a dark round receptacle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and green in color with petals that are curled upward ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has rows of thick green sepals surrounding a fringe of thin hairlike purple petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a large flower that seems to be entirely long purple stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with ragged white and purple petals and with a cluster of white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is bright pink with broad petals with multiple points and bright pink center stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has pink and red petals with a red anther ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white in color with petals that are ruffled on the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a bright pink coloring with white around the edges and in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with pink trim ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a cluster of flowers with red petals and white anther filaments and pistils ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are pink with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a cluster of flowers with purple and white petals and white pistils ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with white edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this white flower with white filaments has medium purple colored lines toward the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a flower with pink ruffled petals with white tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'there are several orange and pink petals that are stacked on top of each other ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this brightly colored red flower has petals that are not all the way opened ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are white with purple trim and are smooth ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow and pink in color with petals that are ruffled and bunched together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this pink flower has many overlapping layers of petals which are very ruffled ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are ruffled around the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pretty flower has white petals with pink at their center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'these flowers are mostly pink but some of them have white parts located closer to their stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'small oval shaped petals arranged in a circular manner having white shades in the bottom of the petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are pink in color and are arranged in numbers of five ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this spiny petaled lilac flower has spiral looking green stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower had many purplish blue flat pointed petals with light green stamen and thin pointy leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are blue with green stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'stamens are many with larger green anthers petals are light blue in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pretty flowers has white petals and yellow in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with yellow stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has start shaped purple petals as its main feature ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has a large pistil and feathery grayish petals as its main feature ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has spiky blue petals and a spiky black stigma on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has interesting frost tipped petals that are blue purple in appearance ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the leaves are green in color the petals are larger and broader ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and white in color with petals that are ruffled at the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has orange and red mouth colors surrounded by pink petals with ruffled edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are white with a long stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are white with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the white and purple petals on this flower sit atop a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a purple flower with ruffled petals and large green sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long white petals and a center without a stigma on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has purple petals and pistil with green pedicel ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'some sparse thin pink petals surround a very long pistil with green stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are pink in color while the filaments are also pink ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this pink flower has long narrow petals with a long narrow pollen tube ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color and has petals that are wavy and skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flower has violet colored petals with purple anthers and pink filament ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long pink petals and long pink stamen in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower petals are needle shaped and are light pink in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are pink with a long stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has pink and white petals along with a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are curled and skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'what i like about this flower is its uniquely shaped petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has large light pink petals that are thin and sharp ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flower with white petals with a green tip and purple stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and pink in color with petals that are pink near the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and green in color with petals that are ppointed on the ends ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has large white petal and a lot of white stamen in the center of it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are pink with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower petals are alternately arranged and are light pink in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has pointed layered petals that are lavender in color with pointed tips that are brown ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a large green pedicel and large pink petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are curled downward ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and green in color with petals that are spotted near the ovule ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has yellow petals overlapping each other and are yellow in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with many short stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals are oval in shape and are whit in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are layered ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and black in color with petals that are oval shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has numerous stamen ringed by multiple layers of thin pink petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has bright orange petals with a yellow inner ring ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is a combination of light red and orange with many petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are red in color and have green leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this droopy white flower has a trumpet shaped blossom surrounded by several large wide slightly pointed white petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are ruffled on the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow pistil and yellow petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'what standout about this flower is its rich canary color and diamond shaped petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are yellow with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has large bright yellow petals yellow stamens and a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are orange in color and have thin filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has pinkish petals that are pointed with a faint white line down the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has pink and white petals with green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with yellow shading ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals are broad but thin at the edges with purple tints at the edges and white in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange and yellow in color with petals that are ruffled on the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange and red in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white pink and yellow in color and has petals that are wacy ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this pink white and yellow flower has large scalped pedals with purple filaments jetting up from a green center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange in color with petals that are rounded and wavy ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower is white with petals that are soft smooth and arranged around stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow and orange in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with yellow spots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red and yellow in color with petals that are red on the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are yellow with purple edges purple anther and yellow filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flowers are alternately shaped they are light pink in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has large red petals that are oval shaped and long ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are large pointed and dark red ', shape=(), dtype=string)
# captions:  tf.Tensor(b'these white veiny flowers have large leaf like petals and green stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are pointed on the ends ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are leaf like ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is bright pink with a white outer color on its petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are pink with green stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower appears to be blooming but has really cool red leaves you don t see that everyday ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink in color with petals that are leaf like ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has pointy faded pink petals that are white around their edges and have deep green veins ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'these bright red flowers have thick wavy petals and green stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and green in color with petals that are leaf like ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple and folded together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has purple petals with green pollen tubes and yellow anther ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with medium purple petals accompanied by yellow anther filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are large and pink with yellow anther ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are overlapping and yellow with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a flower that has round shaped orange petals on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a bunch of yellow petals with red tips and a purple stamen in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has bright red petals with green pedicel as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a bright orange colored cluster of blooms on a long green and burgundy colored stem ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this small flower has several smooth orange petals with round edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a red flower with round petals and a touch of purple berries ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower is red with petals that are soft separated and surrounding the stamen that has white anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange in color with petals that are wavy and curled ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has small yellow and orange petals with white anther ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with patches of orange ', shape=(), dtype=string)
# captions:  tf.Tensor(b'these flowers have bright red petals and small white details at the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are yellow and are different in shape ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red in color with petals that are rounded ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange and white in color with petals that are rounded ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this pretty flower has yellow and orange petals with a white center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are orange with white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow and orange in color with petals that are ruffled along the edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has small red petals and a couple of white anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has veined and overlapping orange petals with rounded edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has yellow petals with white anther and filament ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this small flower has smooth rounded petals in red with orange edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has bright yellow petals and green pedicel and sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has little yellow petals and green pedicel as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'sepals are green in color petals are floret and are yellow in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow and ruffled together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow and ruffled together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are bunched closely together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flower with bright yellow petals formed in a tight cluster ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are yellow and have curled edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are rounded ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has broad dark yellow petals and matching yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are rounded ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has thin yellow petals as its main feature ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a lot of yellow stamen and numerous skinny and long white petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are white with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with white petals and a with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow and very thin ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are skinny and long ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals are oval in shape and are yellow in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow pistil and tiny yellow petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow in color with petals that are skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a numerous amount of thin bright yellow petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are yellow in color and have stems that are green in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are very thin and also yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are yellow with no visible stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown green pedicel and sepal with a white petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a single petal which is white and yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has large red petals and no visible outer stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red in color with petals that are wavy and vonnected ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower features a frame of delicate red petals surrounding a yellow center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a group of flowers with pinkish red petals and no visible pistils ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with diffrent shades of purple on its petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'broad bright red petals pulled together into an almost star shape with a yellow pistil area ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this bright fuchsia flower has several conjoined petals with slightly ruffled edges ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'this flower has petals that are red with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this trumpet shaped flower has several conjoined white petals with ruffled edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a wrinkled petal that is white with green veins ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has white petals with green lines and wavy edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has green sepal and pedicel with white petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has white petals with green lines on the inside of each petal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and yellow in color with petals that have veins ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with yellow lines ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with yellow patches ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has white petals that are green where they meet the sepal and have green veins throughout the white ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals are joint on the bottom and open on top like a bell ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has large white petals and no visible outer stamen in it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a white and yellow veiny flower with star shaped petals and tiny stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flower with large white petals and narrow deep receptacle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this horn shaped flower has one large petal and a few yellow stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'lavender and white pedal and yellow small flower in the middle of the pedals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a large medium pink flower with a white ring before the pink and the middle is green and yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has round edged petals that are purple with white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this colorful flower has neon pink petals and a green stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'purple and white petals white middle green leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has bright pink petals that are wide and flat ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has pink and purple petals with a pink stigma and green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has pink petals with a yellow pollen tube in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and pink in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'these flowers has bright purple flower with a dark purple center and a light purple stem ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white purple and yellow in color with petals that are striped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'there are several flowers with large round petals that are violet and lavender in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower displays three colors on its petals white light purple and yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flowers has petals that are white and yellow with yellow filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with yellow and white patches with black lines ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pedals of this flower are purple and yellow with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is bright red along the edges of the circular petals and yellow towards the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'yellow stigma centered inside of bright yellow with red bordered petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow and white in color with petals that are star shaped near the cener ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow petals with a tad of orange and a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are orange with yellow edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this beauty has yellow petals with a small yellow in its stamen in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has curled pink petals and a yellow pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'five white petals yellow centers are arranged around six pistils ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower is disc shaped and has soft smooth and thin petals and has stamens in the centre ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow and bunched together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a bright yellow center surrounded by deep indigo petals which are heart shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has oval shapd petals that are yellow in color with larger green sepals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the yellow flower has petals that are soft smooth and arranged separately around bunch of stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a broad center of many brown stamen surrounded by many long narrow pointy yellow petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this large flower has sharp layer of yellow leaves with numerous anthers in disc in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a wide brown center surrounded by long yellow petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long and skinny yellow petals and a group of brown anthers on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a purple flower with white on the petals and anther filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a white base at the pedals extending towards a purple top with medium sized receptacles ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are lavender with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a purple and white veiny flower with rounded petals and a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has layered purple petals with white stamen and pistil in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flat and overlapping purple petal has a round shape the stamen is flat as well ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals are delicate and light purple in color with rounded ends and the stamen is white ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a red petal and a group of yellow stamen in the middle ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has several layers of red petals and a red center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'red stacked petals surround yellow stamen and a black pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has red petals and red stamen with bright yellow anthers on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow pistil and small red petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are red in color and have a center that is made of yellow anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with yellow stigma ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'this is a red double flower that has soft petals and yellow stamens in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white in color with petals that are oval shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has small white petals with long white stamen in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has small white petals and white pistil as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red and ruffled together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this small blossom has several rounded petals in shades of red which angle slightly upwards ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a dense amount of red petals that are round ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a lot of red petals and one red anther in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red and bunched together ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flowers are many ina bunch and are orange in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a red colored petal with a red colored stigma ', shape=(), dtype=string)
# ...
# captions:  tf.Tensor(b'the pedals of this flower are pink with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has round light pink petals that point up ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are pink in color with a dark pink base at the bottom ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'this flower is white and pink in color with petals that are oval shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are white with no visible stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has five wide overlapping orange petals with rounded slightly ruffled edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a peach and white petal with orange anther in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has yellow pistil and smooth pink petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange and yellow in color and has petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with yellow petals accompanied by yellow pistils and anther filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the large orange round petals and lightly dripped in water ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow with red blotches ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange in color with petals that are rounded ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a flower with orange petals and a green pedicel ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has round petals that are yellow and orange ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are orange with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red and yellow in color with petals that are ruffled ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are orange with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a large bright orange petal with pink anther ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are orange with orange stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange in color with petals that are ruffled and darker near the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are white and orange with a long stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is composed of five rounded yellow petals with orange brush bases and yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'petals are rounded in shape they are orange in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is orange and yellow in color with petals that are spotted ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the large petaled orange and yellow flowers have stamen that are hidden between the center petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are yellow with two orange dotted petals and yellow stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow and orange in color with petals that are spotted ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has dark orange almost redish petals that open backwards around the very thin yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has large yellow petals and no visible outer stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a large yellow and orange flower the petals fade from yellow to orange in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are orange with yellow shading ', shape=(), dtype=string)
# captions:  tf.Tensor(b'sepals are green i n color flower petals are yellow and brown spotted in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has green sepals the petals are white in color and larger anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pedicel has a single flower which is red and white ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with light green centers and white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has green pedicel and pink petals as its main features ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and orange in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flower has pink and white medium size pedals with white long thin pistils ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this white and pale pink flower has darker pink veins on the petals and the anthers are yellow ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are red with large green stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and pink in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are white with deep red veins ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red in color with petals that are curled and skinny ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has the dark pink colored petals with the prominent pink pollen tube arranged clumsy ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red and black in color and has petals that are skinny and wavy ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with ruffled tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has bright pink and purple petals as its main feature ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple and pink in color with petals that are pointed ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with dark dots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with dark dots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with purple petals and black spots with no visible anther filaments ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple and white in color with petals that are spotted on the inside ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and purple in color and has petals that are spotted ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with a single tubular white and black dotted petal and white stamen cluster ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has purple petals with white spots and green sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with purple dots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are tubular in nature and grow in bunches like grapes ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and white in color with petals that are spotted on the inside ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has white petals in shaped of bells with green sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and white in color with petals that are spotted on the insides ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this purple and white flower has dark spots on the inside of the bell shaped petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has bell shaped purple petals with dark spots on them ', shape=(), dtype=string)
# captions:  tf.Tensor(b'these flower is like a little tube with a polka dot pattern inside the petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and white in color with petals that are spotted on the inside ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has a set of bell shaped petals with its inner core filled with black dots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has purple leaves with white and purple details green sepal and green pedicel ', shape=(), dtype=string)
# (64,)
# captions:  tf.Tensor(b'the flower has petals that are white bell shaped and have white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with white patches ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this plant has wife trunoer shaped white blossoms with purple spots arranged vertically along the stem ', shape=(), dtype=string)
# captions:  tf.Tensor(b'many clusters in a long shape with purple bell shaped flowers with white and red spots in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are pink with a short stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with patches of white ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a single layer of bright pink purple large petals with a center area that is white ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a tiny white blossom in the center surrounded by pointed purple petals with leaflike veins ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has bright purple petals that appear to be independent of each other ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals on this flower are purple with small white flowers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are dark pink with white stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this medium pink flower has several petals a slim predicel three white stamen and multiple mid sized leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of this flower are peach with a long stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has light pink petals that are large and thick ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower shown has white and red pistil with smooth purple petals ', shape=(), dtype=string)
# captions:  tf.Tensor(b'smooth large orange petal with a green filament and a pink anthem ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this is a big flower with long green leaves white petals and yellow stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'fat and wide pink flower with a yellow center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has pink flowers green sepal and pedicel and yellow anther ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the petals of the flower are hot pink and have an orange center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are pink with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red and white in color with petals that have veins ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower is bell shaped and has petals that are red with single layer and a enclosing the stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'thin almost transparent yellow petals surrounding a dark yellow pistil and green sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has thick red petals as its main feature ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and yellow in color with petals that are ruffled ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple in color with petals that are wrinkled in appearance ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has light blue petals and dark blue stamen on the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is purple in color with petals that are ruffled ', shape=(), dtype=string)
# captions:  tf.Tensor(b'vibrant purple petals forming a deep cup meeting at a slender sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with a ruffled texture ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are purple with white stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a pointy and orange petal with a yellow stigma ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red in color with petals that are pointed at the tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flowers has a strange looking red petals that looks very similar to it s leaves ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with yellow tips ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has many long red petals with rounded yellow tips surrounding a dark red center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has several small long red petals with yellow tips surrounding a large burgundy and yellow ovule ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red and yellow in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'flower has oval shaped petals that are red and yellow in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is red in color with petals that are horn shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is pink and yellow in color with petals that are horn shaped ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has red petals as well as a green pedicel and sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are red with yellow steman ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has five very large wide red petals with rounded edges ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a long orange petal with yellow dots on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has long red petals and long orange stigma in the center of it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has bright yellow leaves with deep orange color spots on them ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is yellow and pink in color with petals that are spotted ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the flower has petals that are yellow with orange spots ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this white and purple flower has fragile petals and soft stamens ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has four large wide pink petals with white centers and vein like markings ', shape=(), dtype=string)
# captions:  tf.Tensor(b'a flower with broad white and pink ribbed petals and yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'one prominet pistil with alarger stigam and many stamens with anthers ', shape=(), dtype=string)
# captions:  tf.Tensor(b'leaves are green in color petals are light pink in color ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is bright pink with overlapping petals and a lime green pistil ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white and yellow in color with petals that are multi colored ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has 4 leaves three are purple and yellow with lines and one is solid purple ', shape=(), dtype=string)
# captions:  tf.Tensor(b'the pretty flower has dark and white petals on it ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has petals that are white with yellow stamen ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is trumpet shaped with a light pink petal and green sepal ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower has a few bright pink petals that turn more white in the center ', shape=(), dtype=string)
# captions:  tf.Tensor(b'this flower is white in color with petals that are wavy and uneven ', shape=(), dtype=string)
# (64,)
# Time for inference is 1.5420 sec

# %% [markdown]
# # combine picture

# %%
import cv2

img1 = cv2.imread('/home/yuan65536/DL-hw/kaggle03/inference/demo_final/temp1/inference_0000.jpg')
img2 = cv2.imread('/home/yuan65536/DL-hw/kaggle03/inference/demo_final/temp1/inference_0001.jpg')
img3 = cv2.imread('/home/yuan65536/DL-hw/kaggle03/inference/demo_final/temp1/inference_0002.jpg')
img4 = cv2.imread('/home/yuan65536/DL-hw/kaggle03/inference/demo_final/temp1/inference_0003.jpg')
img5 = cv2.imread('/home/yuan65536/DL-hw/kaggle03/inference/demo_final/temp1/inference_0004.jpg')

h_img = cv2.hconcat([img1, img2,img3,img4,img5])


cv2.imshow('Vertical', h_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
