# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
import tensorflow_addons as tfa
import os

import string
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import random
import time
from pathlib import Path

from tqdm import tqdm

import re
from IPython import display

BATCH_SIZE = 64
# Out:
# /home/wangyuwen/.local/lib/python3.6/site-packages/tensorflow_addons/utils/ensure_tf_install.py:67: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.4.0 and strictly below 2.7.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.3.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   UserWarning,

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
x_train = np.load('/home/Datasets/kaggle4_cifar10/x_train_cifar10_unlearn.npy')
y_train = np.load('/home/Datasets/kaggle4_cifar10/y_train_cifar10.npy')
x_val = np.load('/home/Datasets/kaggle4_cifar10/x_val_cifar10.npy')
y_val = np.load('/home/Datasets/kaggle4_cifar10/y_val_cifar10.npy')
x_test = np.load('/home/Datasets/kaggle4_cifar10/x_test_cifar10.npy')

y_train = np.argmax(y_train, axis=1)
y_val = np.argmax(y_val, axis=1)

# %%
def rgb2gray(img_dir):
    res = []
    for i in range(len(img_dir)):
        img = img_dir[i]*255
        img = img.astype(np.uint8)
        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray_img = gray_img/255
        res.append(gray_img)
        
    return np.asarray(res)

# %%
def dummy_rgb(gray):
    dummy_RGB_images = np.repeat(gray[..., np.newaxis], 3, -1)
    
    return dummy_RGB_images

# %%
x_gray_train = rgb2gray(x_train)
x_gray_val = rgb2gray(x_val)
x_gray_test = rgb2gray(x_test)

#x_gray_train = x_gray_train.reshape(len(x_gray_train), 32, 32, 1)
#x_gray_val = x_gray_val.reshape(len(x_gray_val), 32, 32, 1)

dummy_train = dummy_rgb(x_gray_train)
dummy_val = dummy_rgb(x_gray_val)
dummy_test = dummy_rgb(x_gray_test)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dummy_train, y_train))
train_dataset = train_dataset.shuffle(100)
batched_dataset = train_dataset.batch(BATCH_SIZE, drop_remainder=True)

val_dataset = tf.data.Dataset.from_tensor_slices((dummy_val, y_val))
val_dataset = val_dataset.shuffle(100)
batched_val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
for data in batched_dataset.take(1):
    plt.imshow(data[0][3], cmap='gray')

# %%
densenet = tf.keras.applications.densenet.DenseNet201(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 3), pooling=None
)

# %%
model = Sequential()

# %%
model.add(densenet)
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.7))
model.add(layers.BatchNormalization())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Functional)     (None, 1, 1, 1920)        18321984
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1920)              7680
# _________________________________________________________________
# dense (Dense)                (None, 512)               983552
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 19,482,314
# Trainable params: 19,247,626
# Non-trainable params: 234,688
# _________________________________________________________________

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['acc'])

# %%
checkpoint_filepath = './ckpt/checkpoint{epoch}/'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_filepath, save_weights_only = True,
    monitor = 'val_acc', mode = 'max', save_best_only = True
)

# %%
history = model.fit(x=batched_dataset, validation_data=batched_val_dataset, epochs=200, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 68s 54ms/step - loss: 2.3250 - acc: 0.1682 - val_loss: 2.9940 - val_acc: 0.1083
# Epoch 2/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 1.8865 - acc: 0.2835 - val_loss: 2.7464 - val_acc: 0.1665
# Epoch 3/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 1.6985 - acc: 0.3735 - val_loss: 1.8388 - val_acc: 0.3305
# Epoch 4/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 1.5736 - acc: 0.4383 - val_loss: 3.0179 - val_acc: 0.2227
# Epoch 5/200
# 1250/1250 [==============================] - 67s 53ms/step - loss: 1.4884 - acc: 0.4816 - val_loss: 2.0553 - val_acc: 0.3500
# Epoch 6/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 1.3589 - acc: 0.5415 - val_loss: 1.5474 - val_acc: 0.4718
# Epoch 7/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 1.2574 - acc: 0.5829 - val_loss: 1.3172 - val_acc: 0.5460
# Epoch 8/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 1.2037 - acc: 0.6050 - val_loss: 1.9075 - val_acc: 0.4188
# Epoch 9/200
# 1250/1250 [==============================] - 68s 54ms/step - loss: 1.0767 - acc: 0.6528 - val_loss: 1.4040 - val_acc: 0.5395
# Epoch 10/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.9792 - acc: 0.6858 - val_loss: 1.7992 - val_acc: 0.4723
# Epoch 11/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.9247 - acc: 0.7042 - val_loss: 1.3909 - val_acc: 0.5322
# Epoch 12/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.8320 - acc: 0.7387 - val_loss: 1.2914 - val_acc: 0.5893
# Epoch 13/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.8077 - acc: 0.7448 - val_loss: 1.4324 - val_acc: 0.5600
# Epoch 14/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.7055 - acc: 0.7814 - val_loss: 1.5554 - val_acc: 0.5347
# Epoch 15/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.6706 - acc: 0.7920 - val_loss: 1.8853 - val_acc: 0.5128
# Epoch 16/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.6585 - acc: 0.7965 - val_loss: 1.2516 - val_acc: 0.6102
# Epoch 17/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.5950 - acc: 0.8189 - val_loss: 1.8113 - val_acc: 0.4888
# Epoch 18/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.6116 - acc: 0.8135 - val_loss: 1.2057 - val_acc: 0.6190
# Epoch 19/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.4906 - acc: 0.8526 - val_loss: 1.3711 - val_acc: 0.6181
# Epoch 20/200
# 1250/1250 [==============================] - 72s 57ms/step - loss: 0.4086 - acc: 0.8774 - val_loss: 1.2355 - val_acc: 0.6429
# Epoch 21/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.4376 - acc: 0.8687 - val_loss: 1.3597 - val_acc: 0.6401
# Epoch 22/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.3656 - acc: 0.8910 - val_loss: 1.5260 - val_acc: 0.6120
# Epoch 23/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.3293 - acc: 0.9027 - val_loss: 1.4979 - val_acc: 0.6287
# Epoch 24/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.2987 - acc: 0.9132 - val_loss: 1.5120 - val_acc: 0.6173
# Epoch 25/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.3101 - acc: 0.9101 - val_loss: 1.5024 - val_acc: 0.6348
# Epoch 26/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.2430 - acc: 0.9304 - val_loss: 1.5318 - val_acc: 0.6273
# Epoch 27/200
# 1250/1250 [==============================] - 68s 55ms/step - loss: 0.3097 - acc: 0.9128 - val_loss: 1.4606 - val_acc: 0.6278
# Epoch 28/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.2284 - acc: 0.9346 - val_loss: 1.5825 - val_acc: 0.6379
# Epoch 29/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.2110 - acc: 0.9411 - val_loss: 1.7098 - val_acc: 0.6177
# Epoch 30/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.2835 - acc: 0.9208 - val_loss: 1.4005 - val_acc: 0.6303
# Epoch 31/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.1737 - acc: 0.9525 - val_loss: 1.5567 - val_acc: 0.6484
# Epoch 32/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.2502 - acc: 0.9300 - val_loss: 1.4227 - val_acc: 0.6557
# Epoch 33/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.2062 - acc: 0.9450 - val_loss: 1.7324 - val_acc: 0.6265
# Epoch 34/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1814 - acc: 0.9525 - val_loss: 4.2121 - val_acc: 0.4280
# Epoch 35/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.2258 - acc: 0.9374 - val_loss: 1.4400 - val_acc: 0.6714
# Epoch 36/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1406 - acc: 0.9616 - val_loss: 1.6391 - val_acc: 0.6478
# Epoch 37/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.2090 - acc: 0.9427 - val_loss: 1.8116 - val_acc: 0.5702
# Epoch 38/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1307 - acc: 0.9661 - val_loss: 1.6861 - val_acc: 0.6473
# Epoch 39/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1375 - acc: 0.9632 - val_loss: 1.8179 - val_acc: 0.6390
# Epoch 40/200
# 1250/1250 [==============================] - 66s 52ms/step - loss: 0.1265 - acc: 0.9654 - val_loss: 1.8792 - val_acc: 0.6307
# Epoch 41/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1310 - acc: 0.9650 - val_loss: 1.7215 - val_acc: 0.6360
# Epoch 42/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1584 - acc: 0.9575 - val_loss: 1.7116 - val_acc: 0.6501
# Epoch 43/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.1126 - acc: 0.9707 - val_loss: 1.9433 - val_acc: 0.6202
# Epoch 44/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.1119 - acc: 0.9714 - val_loss: 2.0691 - val_acc: 0.5922
# Epoch 45/200
# 1250/1250 [==============================] - 66s 52ms/step - loss: 0.1039 - acc: 0.9737 - val_loss: 1.9522 - val_acc: 0.6259
# Epoch 46/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.1342 - acc: 0.9644 - val_loss: 2.2286 - val_acc: 0.5780
# Epoch 47/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.1155 - acc: 0.9701 - val_loss: 1.5911 - val_acc: 0.6417
# Epoch 48/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.1282 - acc: 0.9670 - val_loss: 1.5769 - val_acc: 0.6596
# Epoch 49/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0811 - acc: 0.9793 - val_loss: 1.9147 - val_acc: 0.6374
# Epoch 50/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.1159 - acc: 0.9696 - val_loss: 1.6797 - val_acc: 0.6539
# Epoch 51/200
# 1250/1250 [==============================] - 68s 54ms/step - loss: 0.0764 - acc: 0.9798 - val_loss: 2.0668 - val_acc: 0.6255
# Epoch 52/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.2146 - acc: 0.9440 - val_loss: 2.7793 - val_acc: 0.3961
# Epoch 53/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.1437 - acc: 0.9601 - val_loss: 1.6205 - val_acc: 0.6644
# Epoch 54/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0708 - acc: 0.9821 - val_loss: 2.0901 - val_acc: 0.6030
# Epoch 55/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0742 - acc: 0.9816 - val_loss: 1.8165 - val_acc: 0.6471
# Epoch 56/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0853 - acc: 0.9779 - val_loss: 2.0691 - val_acc: 0.5997
# Epoch 57/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0883 - acc: 0.9776 - val_loss: 1.7772 - val_acc: 0.6526
# Epoch 58/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0802 - acc: 0.9793 - val_loss: 1.8305 - val_acc: 0.6202
# Epoch 59/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.0754 - acc: 0.9805 - val_loss: 1.9669 - val_acc: 0.6302
# Epoch 60/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.0863 - acc: 0.9781 - val_loss: 1.6606 - val_acc: 0.6538
# Epoch 61/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.0762 - acc: 0.9807 - val_loss: 1.8331 - val_acc: 0.6425
# Epoch 62/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.0757 - acc: 0.9811 - val_loss: 1.6262 - val_acc: 0.6673
# Epoch 63/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.0908 - acc: 0.9773 - val_loss: 1.7496 - val_acc: 0.6267
# Epoch 64/200
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.1024 - acc: 0.9747 - val_loss: 1.6403 - val_acc: 0.6668
# Epoch 65/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.0619 - acc: 0.9834 - val_loss: 1.8804 - val_acc: 0.6386
# Epoch 66/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.0613 - acc: 0.9842 - val_loss: 2.2652 - val_acc: 0.5932
# Epoch 67/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.0672 - acc: 0.9827 - val_loss: 1.9860 - val_acc: 0.6319
# Epoch 68/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.0945 - acc: 0.9769 - val_loss: 1.7506 - val_acc: 0.6517
# Epoch 69/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0556 - acc: 0.9861 - val_loss: 1.8917 - val_acc: 0.6445
# Epoch 70/200
# 1250/1250 [==============================] - 66s 52ms/step - loss: 0.0655 - acc: 0.9837 - val_loss: 2.6507 - val_acc: 0.5488
# Epoch 71/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0644 - acc: 0.9833 - val_loss: 1.9831 - val_acc: 0.6356
# Epoch 72/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0621 - acc: 0.9840 - val_loss: 1.9637 - val_acc: 0.6359
# Epoch 73/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0578 - acc: 0.9851 - val_loss: 1.8242 - val_acc: 0.6593
# Epoch 74/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0605 - acc: 0.9848 - val_loss: 1.9472 - val_acc: 0.6208
# Epoch 75/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0562 - acc: 0.9861 - val_loss: 1.8464 - val_acc: 0.6566
# Epoch 76/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0569 - acc: 0.9861 - val_loss: 1.9092 - val_acc: 0.6584
# Epoch 77/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0615 - acc: 0.9844 - val_loss: 1.8489 - val_acc: 0.6565
# Epoch 78/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0563 - acc: 0.9863 - val_loss: 1.8525 - val_acc: 0.6512
# Epoch 79/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0562 - acc: 0.9858 - val_loss: 1.9597 - val_acc: 0.6503
# Epoch 80/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0796 - acc: 0.9808 - val_loss: 1.6808 - val_acc: 0.6639
# Epoch 81/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0673 - acc: 0.9829 - val_loss: 1.7497 - val_acc: 0.6637
# Epoch 82/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0478 - acc: 0.9883 - val_loss: 1.9225 - val_acc: 0.6394
# Epoch 83/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0469 - acc: 0.9879 - val_loss: 1.8695 - val_acc: 0.6638
# Epoch 84/200
# 1250/1250 [==============================] - 66s 52ms/step - loss: 0.1194 - acc: 0.9716 - val_loss: 1.6462 - val_acc: 0.6760
# Epoch 85/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0366 - acc: 0.9910 - val_loss: 1.9608 - val_acc: 0.6506
# Epoch 86/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0444 - acc: 0.9888 - val_loss: 2.1628 - val_acc: 0.6364
# Epoch 87/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0643 - acc: 0.9837 - val_loss: 2.0153 - val_acc: 0.6412
# Epoch 88/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0637 - acc: 0.9850 - val_loss: 1.9731 - val_acc: 0.6332
# Epoch 89/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0550 - acc: 0.9866 - val_loss: 2.1797 - val_acc: 0.6101
# Epoch 90/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0875 - acc: 0.9784 - val_loss: 1.6707 - val_acc: 0.6755
# Epoch 91/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0307 - acc: 0.9926 - val_loss: 2.0489 - val_acc: 0.6423
# Epoch 92/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0532 - acc: 0.9872 - val_loss: 2.1607 - val_acc: 0.6305
# Epoch 93/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0972 - acc: 0.9760 - val_loss: 1.9254 - val_acc: 0.6548
# Epoch 94/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0344 - acc: 0.9920 - val_loss: 2.0733 - val_acc: 0.6320
# Epoch 95/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0453 - acc: 0.9893 - val_loss: 2.0130 - val_acc: 0.6195
# Epoch 96/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0479 - acc: 0.9883 - val_loss: 1.9450 - val_acc: 0.6550
# Epoch 97/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0474 - acc: 0.9879 - val_loss: 1.8370 - val_acc: 0.6554
# Epoch 98/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0414 - acc: 0.9898 - val_loss: 1.8891 - val_acc: 0.6419
# Epoch 99/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0476 - acc: 0.9884 - val_loss: 2.0190 - val_acc: 0.6451
# Epoch 100/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0480 - acc: 0.9888 - val_loss: 1.7004 - val_acc: 0.6685
# Epoch 101/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0390 - acc: 0.9903 - val_loss: 1.9747 - val_acc: 0.6430
# Epoch 102/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0412 - acc: 0.9898 - val_loss: 2.0454 - val_acc: 0.6447
# Epoch 103/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0482 - acc: 0.9886 - val_loss: 1.7877 - val_acc: 0.6635
# Epoch 104/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0403 - acc: 0.9897 - val_loss: 1.9001 - val_acc: 0.6553
# Epoch 105/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0382 - acc: 0.9910 - val_loss: 1.9148 - val_acc: 0.6467
# Epoch 106/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0600 - acc: 0.9852 - val_loss: 1.6480 - val_acc: 0.6663
# Epoch 107/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0510 - acc: 0.9882 - val_loss: 1.8005 - val_acc: 0.6693
# Epoch 108/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0341 - acc: 0.9918 - val_loss: 1.7695 - val_acc: 0.6821
# Epoch 109/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0589 - acc: 0.9859 - val_loss: 1.7662 - val_acc: 0.6664
# Epoch 110/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0422 - acc: 0.9905 - val_loss: 1.7439 - val_acc: 0.6796
# Epoch 111/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0292 - acc: 0.9932 - val_loss: 2.0559 - val_acc: 0.6487
# Epoch 112/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0396 - acc: 0.9900 - val_loss: 1.8804 - val_acc: 0.6632
# Epoch 113/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0348 - acc: 0.9910 - val_loss: 2.1391 - val_acc: 0.6444
# Epoch 114/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0895 - acc: 0.9786 - val_loss: 1.8375 - val_acc: 0.6147
# Epoch 115/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0647 - acc: 0.9837 - val_loss: 1.6757 - val_acc: 0.6706
# Epoch 116/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0219 - acc: 0.9948 - val_loss: 2.0738 - val_acc: 0.6398
# Epoch 117/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0312 - acc: 0.9926 - val_loss: 2.0594 - val_acc: 0.6476
# Epoch 118/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0349 - acc: 0.9918 - val_loss: 2.0081 - val_acc: 0.6352
# Epoch 119/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0361 - acc: 0.9909 - val_loss: 1.9009 - val_acc: 0.6691
# Epoch 120/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0389 - acc: 0.9903 - val_loss: 2.1466 - val_acc: 0.6355
# Epoch 121/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0465 - acc: 0.9894 - val_loss: 1.9506 - val_acc: 0.6659
# Epoch 122/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0374 - acc: 0.9914 - val_loss: 1.9102 - val_acc: 0.6433
# Epoch 123/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0405 - acc: 0.9904 - val_loss: 2.0491 - val_acc: 0.6485
# Epoch 124/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0357 - acc: 0.9916 - val_loss: 2.0339 - val_acc: 0.6321
# Epoch 125/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0425 - acc: 0.9896 - val_loss: 1.8050 - val_acc: 0.6622
# Epoch 126/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0293 - acc: 0.9930 - val_loss: 2.3037 - val_acc: 0.6121
# Epoch 127/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0309 - acc: 0.9926 - val_loss: 2.1513 - val_acc: 0.6492
# Epoch 128/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0356 - acc: 0.9905 - val_loss: 1.9865 - val_acc: 0.6609
# Epoch 129/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0474 - acc: 0.9887 - val_loss: 1.7749 - val_acc: 0.6687
# Epoch 130/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0358 - acc: 0.9915 - val_loss: 1.9149 - val_acc: 0.6529
# Epoch 131/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0344 - acc: 0.9919 - val_loss: 1.8561 - val_acc: 0.6657
# Epoch 132/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0324 - acc: 0.9923 - val_loss: 1.8199 - val_acc: 0.6664
# Epoch 133/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0428 - acc: 0.9899 - val_loss: 1.7596 - val_acc: 0.6646
# Epoch 134/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0318 - acc: 0.9925 - val_loss: 1.8944 - val_acc: 0.6614
# Epoch 135/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0276 - acc: 0.9936 - val_loss: 2.1096 - val_acc: 0.6525
# Epoch 136/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0401 - acc: 0.9911 - val_loss: 1.8855 - val_acc: 0.6601
# Epoch 137/200
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.0308 - acc: 0.9924 - val_loss: 2.0112 - val_acc: 0.6508
# Epoch 138/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.0296 - acc: 0.9933 - val_loss: 2.2374 - val_acc: 0.6313
# Epoch 139/200
# 1250/1250 [==============================] - 68s 54ms/step - loss: 0.0307 - acc: 0.9926 - val_loss: 2.0233 - val_acc: 0.6442
# Epoch 140/200
# 1250/1250 [==============================] - 68s 55ms/step - loss: 0.0628 - acc: 0.9856 - val_loss: 1.9305 - val_acc: 0.6488
# Epoch 141/200
# 1250/1250 [==============================] - 68s 55ms/step - loss: 0.0225 - acc: 0.9947 - val_loss: 2.0218 - val_acc: 0.6436
# Epoch 142/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.0222 - acc: 0.9943 - val_loss: 2.1086 - val_acc: 0.6393
# Epoch 143/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.0734 - acc: 0.9821 - val_loss: 1.6932 - val_acc: 0.6460
# Epoch 144/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.0225 - acc: 0.9945 - val_loss: 2.0080 - val_acc: 0.6623
# Epoch 145/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0272 - acc: 0.9933 - val_loss: 1.8617 - val_acc: 0.6594
# Epoch 146/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0270 - acc: 0.9943 - val_loss: 2.2198 - val_acc: 0.6304
# Epoch 147/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0298 - acc: 0.9933 - val_loss: 1.9382 - val_acc: 0.6498
# Epoch 148/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0268 - acc: 0.9938 - val_loss: 2.0003 - val_acc: 0.6568
# Epoch 149/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0335 - acc: 0.9923 - val_loss: 1.8182 - val_acc: 0.6660
# Epoch 150/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0263 - acc: 0.9934 - val_loss: 1.9603 - val_acc: 0.6716
# Epoch 151/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0656 - acc: 0.9858 - val_loss: 1.7005 - val_acc: 0.6559
# Epoch 152/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0680 - acc: 0.9838 - val_loss: 1.6715 - val_acc: 0.6658
# Epoch 153/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0211 - acc: 0.9954 - val_loss: 1.9403 - val_acc: 0.6749
# Epoch 154/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0208 - acc: 0.9954 - val_loss: 2.2874 - val_acc: 0.6305
# Epoch 155/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0354 - acc: 0.9922 - val_loss: 1.9481 - val_acc: 0.6555
# Epoch 156/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.0333 - acc: 0.9921 - val_loss: 1.8301 - val_acc: 0.6684
# Epoch 157/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0303 - acc: 0.9930 - val_loss: 1.8654 - val_acc: 0.6700
# Epoch 158/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0258 - acc: 0.9940 - val_loss: 1.9879 - val_acc: 0.6625
# Epoch 159/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0237 - acc: 0.9948 - val_loss: 2.0595 - val_acc: 0.6626
# Epoch 160/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.0254 - acc: 0.9939 - val_loss: 1.8719 - val_acc: 0.6795
# Epoch 161/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0296 - acc: 0.9930 - val_loss: 2.0092 - val_acc: 0.6385
# Epoch 162/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0255 - acc: 0.9943 - val_loss: 2.1419 - val_acc: 0.6416
# Epoch 163/200
# 1250/1250 [==============================] - 71s 56ms/step - loss: 0.0277 - acc: 0.9933 - val_loss: 2.1645 - val_acc: 0.6146
# Epoch 164/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0595 - acc: 0.9855 - val_loss: 1.8787 - val_acc: 0.6605
# Epoch 165/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0520 - acc: 0.9871 - val_loss: 1.6355 - val_acc: 0.6639
# Epoch 166/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0211 - acc: 0.9951 - val_loss: 1.9675 - val_acc: 0.6615
# Epoch 167/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0155 - acc: 0.9963 - val_loss: 2.0949 - val_acc: 0.6506
# Epoch 168/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0178 - acc: 0.9959 - val_loss: 2.1690 - val_acc: 0.6590
# Epoch 169/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0216 - acc: 0.9948 - val_loss: 2.3774 - val_acc: 0.6282
# Epoch 170/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0284 - acc: 0.9930 - val_loss: 1.9836 - val_acc: 0.6664
# Epoch 171/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0208 - acc: 0.9949 - val_loss: 2.0341 - val_acc: 0.6739
# Epoch 172/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0316 - acc: 0.9933 - val_loss: 1.8510 - val_acc: 0.6642
# Epoch 173/200
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.0400 - acc: 0.9908 - val_loss: 2.1174 - val_acc: 0.6012
# Epoch 174/200
# 1250/1250 [==============================] - 69s 55ms/step - loss: 0.0287 - acc: 0.9927 - val_loss: 1.8048 - val_acc: 0.6740
# Epoch 175/200
# 1250/1250 [==============================] - 68s 54ms/step - loss: 0.0202 - acc: 0.9950 - val_loss: 2.0688 - val_acc: 0.6613
# Epoch 176/200
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.0206 - acc: 0.9952 - val_loss: 2.1410 - val_acc: 0.6487
# Epoch 177/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0243 - acc: 0.9939 - val_loss: 2.0850 - val_acc: 0.6430
# Epoch 178/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0295 - acc: 0.9926 - val_loss: 2.0293 - val_acc: 0.6465
# Epoch 179/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0205 - acc: 0.9952 - val_loss: 1.9387 - val_acc: 0.6599
# Epoch 180/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0469 - acc: 0.9886 - val_loss: 1.8265 - val_acc: 0.6662
# Epoch 181/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0139 - acc: 0.9966 - val_loss: 2.0626 - val_acc: 0.6721
# Epoch 182/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0236 - acc: 0.9947 - val_loss: 1.9744 - val_acc: 0.6433
# Epoch 183/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0227 - acc: 0.9950 - val_loss: 2.0168 - val_acc: 0.6698
# Epoch 184/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0214 - acc: 0.9948 - val_loss: 1.9161 - val_acc: 0.6783
# Epoch 185/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0267 - acc: 0.9934 - val_loss: 2.0283 - val_acc: 0.6645
# Epoch 186/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0250 - acc: 0.9938 - val_loss: 1.8382 - val_acc: 0.6710
# Epoch 187/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0232 - acc: 0.9945 - val_loss: 1.8831 - val_acc: 0.6593
# Epoch 188/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0183 - acc: 0.9959 - val_loss: 2.1451 - val_acc: 0.6511
# Epoch 189/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0260 - acc: 0.9940 - val_loss: 2.0390 - val_acc: 0.6518
# Epoch 190/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0237 - acc: 0.9943 - val_loss: 2.0369 - val_acc: 0.6588
# Epoch 191/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0247 - acc: 0.9940 - val_loss: 2.0969 - val_acc: 0.6500
# Epoch 192/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0288 - acc: 0.9938 - val_loss: 1.8581 - val_acc: 0.6652
# Epoch 193/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0162 - acc: 0.9961 - val_loss: 2.2381 - val_acc: 0.6440
# Epoch 194/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0219 - acc: 0.9954 - val_loss: 2.2363 - val_acc: 0.6325
# Epoch 195/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0536 - acc: 0.9875 - val_loss: 1.8135 - val_acc: 0.6604
# Epoch 196/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0179 - acc: 0.9954 - val_loss: 2.3089 - val_acc: 0.6362
# Epoch 197/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0185 - acc: 0.9954 - val_loss: 2.1806 - val_acc: 0.6554
# Epoch 198/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0193 - acc: 0.9951 - val_loss: 2.1791 - val_acc: 0.6605
# Epoch 199/200
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.0520 - acc: 0.9879 - val_loss: 1.8195 - val_acc: 0.6589
# Epoch 200/200
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.0183 - acc: 0.9955 - val_loss: 1.9958 - val_acc: 0.6769

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.load_weights(checkpoint_filepath.format(epoch=108))

# %%
result = model.predict(dummy_test)

# %%
result = np.argmax(result, axis = 1)

# %%
array = []
for i in range(len(dummy_test)):
    array.append(i)

# %%
d = {'Id': array,'label': result}
output_test_pred = pd.DataFrame(data = d)
output_test_pred.to_csv('test_pred.csv', index = False)
